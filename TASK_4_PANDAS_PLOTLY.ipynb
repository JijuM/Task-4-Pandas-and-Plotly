# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv("college_1.csv")

df2=pd.read_csv("college_2.csv")
len(df1)

#df1.index=range(1,len(df1)+1,1)
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2['python'] = pd.to_numeric(df2['python'], downcast='float')
df2['mysql'] = pd.to_numeric(df2['mysql'], downcast='float')



df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K   100.0          0   31.0                       9
# 1                  Chandru     0.0         20    0.0                       0
# 2        Ganesh Ramkumar R    -1.0         55   24.0                       6
# 3          Bodipudi Harini    -1.0          0   35.0                      -1
# 4                VIINU V P    -1.0        100   24.0                      -1
# 5               Poojitha Y     0.0         78   35.0                       0
# 6   Gowtham Chandrasekaran    -1.0          0    0.0                       3
# 7                Gowtham R    -1.0         60    4.0                       6
# 8                 shifak N    58.0          0    0.0                       0
# 9                  Balaji     -1.0        100   20.0                       0
# 10                Rushitha    -1.0         15   62.0                       9
# ...

# %%
df2_CK=df2.drop(columns=['python_en', 'computational_thinking'])

df2_CK
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0            ASHOK KUMAR K   100.0   31.0              19400           19400
# 1                  Chandru     0.0    0.0              14150           14490
# 2        Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3          Bodipudi Harini    -1.0   35.0              10040           10040
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %%
#df2_CK.index=range(85,len(df2)+85,1)
#df2_CK

# %%
merged=pd.concat([df1,df2_CK])
merged
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising
# 0            Computer Science and Engineering       0
# ...

# %%
merged=merged.sort_values(by='CodeKata Score',ascending=False)
merged
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 0   ASHOK KUMAR K   100.0   31.0              19400           19400
# 1         Chandru     0.0    0.0              14150           14490
# ..            ...     ...    ...                ...             ...
# 82   mohamed nabi     0.0    0.0                  0               0
# 79   KarthikeyanS    45.0    0.0                  0               0
# 80       BARATH.P    29.0    0.0                  0               0
# 81  N.Ajith kumar    82.0    0.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %%
merged.index=range(1,len(merged)+1,1)
merged
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 1        A.Dharani    82.0   20.0              24500           24500
# 2      V.JEEVITHA     82.0   20.0              21740           21740
# 3      HEMAVATHI.R   100.0  100.0              19680           19680
# 4    ASHOK KUMAR K   100.0   31.0              19400           19400
# 5          Chandru     0.0    0.0              14150           14490
# ..             ...     ...    ...                ...             ...
# 115   mohamed nabi     0.0    0.0                  0               0
# 116   KarthikeyanS    45.0    0.0                  0               0
# 117       BARATH.P    29.0    0.0                  0               0
# 118  N.Ajith kumar    82.0    0.0                  0               0
# 119      Hariharan    -1.0   -1.0                  0               0
#
#                                  Department  Rising
# 1          Computer Science and Engineering       0
# ...

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
mg1=merged['CodeKata Score']
mg2=merged['Name']

# %%
dfCK=pd.merge(mg2,mg1,left_index=True,right_index=True)

# %%
dfCK=dfCK.sort_values(by=['CodeKata Score'],ascending=False)

# %%
dfCK
# Out:
#               Name  CodeKata Score
# 1        A.Dharani           24500
# 2      V.JEEVITHA            21740
# 3      HEMAVATHI.R           19680
# 4    ASHOK KUMAR K           19400
# 5          Chandru           14490
# ..             ...             ...
# 115   mohamed nabi               0
# 116   KarthikeyanS               0
# 117       BARATH.P               0
# 118  N.Ajith kumar               0
# 119      Hariharan               0
#
# [119 rows x 2 columns]

# %%
exceeded=dfCK[(dfCK['CodeKata Score']>15000)]
exceeded.to_csv('exceeded.csv')

# %%
Reached_expectations=dfCK[(dfCK['CodeKata Score']>10000)&(dfCK['CodeKata Score']<15000)]
Reached_expectations.to_csv('Reached_expectations.csv')

# %%
Needs_Improvement=dfCK[(dfCK['CodeKata Score']>7000)&(dfCK['CodeKata Score']<10000)]
Needs_Improvement.to_csv('Needs_Improvement.csv')

# %%
Unsatisfactory=dfCK[(dfCK['CodeKata Score']<7000)]
Unsatisfactory.to_csv('Unsatisfactory.csv')

# %%
pd.read_csv('exceeded.csv')
# Out:
#    Unnamed: 0           Name  CodeKata Score
# 0           1      A.Dharani           24500
# 1           2    V.JEEVITHA            21740
# 2           3    HEMAVATHI.R           19680
# 3           4  ASHOK KUMAR K           19400

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
X=merged["Previous Geekions"]

Y=merged["CodeKata Score"]

# %%
L=[]

for i in range(1,len(merged)+1):
    Z=(Y[i]-X[i])
    L.append(Z)
AvgGC=sum(L)/len(L)
AvgGCnp=np.mean(L)
print(AvgGC,AvgGCnp)
# Out:
# 209.41176470588235 209.41176470588235

# %% [markdown]
# ###### No of students participated

# %%
len(merged)
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
py=merged["python"]
py
np.mean(py)
# Out:
# 54.35294117647059

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
mergednew=merged.sort_values(by="Rising",ascending=False)
mergednew
mergednew['Name'][0:3]
# Out:
# 14             shifak N
# 27       Narasimhan Y L
# 6     Ganesh Ramkumar R
# Name: Name, dtype: object

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
mergednew1=merged.sort_values(by="Previous Geekions",ascending=False)
mergednew1[0:3]
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 1    A.Dharani    82.0   20.0              24500           24500
# 2  V.JEEVITHA     82.0   20.0              21740           21740
# 3  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
mergednew2.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score')
# Out:
# <AxesSubplot:ylabel='CodeKata Score'>

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
mergednew2["Department"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
